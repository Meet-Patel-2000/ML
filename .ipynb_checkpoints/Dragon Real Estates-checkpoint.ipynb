# %% [markdown]
# ## Dragon Real Estate- Price Predictor

# %%
import pandas as pd

# %%
housing = pd.read_csv("data.csv")

# %%
housing.head()
# Out:
#      CRIM     ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRAT  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296   15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242   17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242   17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222   18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222   18.7
#
#         B  LSTAT  MEDV  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0  396.90   4.98  24.0          NaN          NaN          NaN          NaN
# 1  396.90   9.14  21.6          NaN          NaN          NaN          NaN
# 2  392.83   4.03  34.7          NaN          NaN          NaN          1.0
# 3  394.63   2.94  33.4          NaN          NaN          NaN          NaN
# 4  396.90   5.33  36.2          NaN          NaN          NaN          NaN

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
# CRIM           506 non-null float64
# ZN             506 non-null float64
# INDUS          506 non-null float64
# CHAS           506 non-null int64
# NOX            506 non-null float64
# RM             506 non-null float64
# AGE            506 non-null float64
# DIS            506 non-null float64
# RAD            506 non-null int64
# TAX            506 non-null int64
# PTRAT          506 non-null float64
# B              506 non-null float64
# LSTAT          506 non-null float64
# MEDV           506 non-null float64
# Unnamed: 14    0 non-null float64
# Unnamed: 15    0 non-null float64
# Unnamed: 16    0 non-null float64
# Unnamed: 17    1 non-null float64
# dtypes: float64(15), int64(3)
# memory usage: 71.3 KB

# %%
housing['CHAS'].value_countscounts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
housing.describe()
# Out:
#             CRIM           ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX       PTRAT           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# count  506.000000  506.000000          0.0          0.0          0.0
# mean    12.653063   22.532806          NaN          NaN          NaN
# std      7.141062    9.197104          NaN          NaN          NaN
# min      1.730000    5.000000          NaN          NaN          NaN
# 25%      6.950000   17.025000          NaN          NaN          NaN
# 50%     11.360000   21.200000          NaN          NaN          NaN
# 75%     16.955000   25.000000          NaN          NaN          NaN
# max     37.970000   50.000000          NaN          NaN          NaN
#
#        Unnamed: 17
# count          1.0
# mean           1.0
# std            NaN
# min            1.0
# 25%            1.0
# 50%            1.0
# 75%            1.0
# max            1.0

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C0C23588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C6FBEC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C6FEE488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C7018E88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C7044FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C7073108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C70AC188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C70E42C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C70EBE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C7129088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C73DB608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C74146C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C74507C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C74888C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C74BEA08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C74F7B08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C752EBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C7566D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C759DE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8C75D6FC8>]],
#       dtype=object)

# %% [markdown]
# ## Train-Test Splitting

# %%
import numpy as np

# %%
def split_train_test(data,test_ratio):
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data)*test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(housing,0.2)

# %%
print(f"Rows in train set {len(train_set)}\nRows in test set {len(test_set)} ")
# Out:
# Rows in train set 405
# Rows in test set 101
